# %%
import pandas as pd
import numpy as np
from dateutil.parser import parse

# %%
s2018=pd.read_csv('data/2018.csv')

# %%
s2018

# %%
s2018.info()

# %%
#forgot to add home team and away team as features. Need to add that in
#How I scraped it is set up as away then home, away then home etc...

# %%
grouped = s2018.groupby('game_id')

# %%
random_game=grouped.groups[400974437]

# %%
values=random_game.get_values()

# %%
home_team = [False if s2018.iloc[values]['team'].iloc[i] ==  s2018.iloc[values]['team'].iloc[0] else True for i in range(len(values))]

# %%
home_team

# %%
home_team=[]
for group in list(grouped.groups.fromkeys(s2018['game_id']).keys()): #need the game_id in the same order as the dataframe
    values = grouped.groups[group].get_values()
    home_team.append([False if s2018.iloc[values]['team'].iloc[i] ==  s2018.iloc[values]['team'].iloc[0] else True for i in range(len(values))])
home_team = [item for sublist in home_team for item in sublist] #need to flatten list of lists into just a single list

# %%
s2018['home_team']=pd.Series(home_team)

# %%
s2018[-50:]

# %%
s2018['date'][0]

# %%
dt = parse(s2018['date'][0])
dt

# %%
s2018['date']=pd.Series([parse(s2018['date'][i]) for i in range(len(s2018))])

# %%
s2018['date'].min()

# %%
s2018['days_after_opener'] = s2018['date']-s2018['date'].min()

# %%
s2018.fillna('0',inplace=True)

# %%
s2018.info()

# %%
s2018['FT_made']=s2018['FT'].map(lambda x: x.split('-')[0])
s2018['FT_attempts']=s2018['FT'].map(lambda x: x.split('-')[-1]) #when filled na with '0'

# %%
s2018['3PT_made']=s2018['3PT'].map(lambda x: x.split('-')[0])
s2018['3PT_attempts']=s2018['3PT'].map(lambda x: x.split('-')[-1]) #when filled na with '0'

# %%
s2018['FG_made']=s2018['FG'].map(lambda x: x.split('-')[0])
s2018['FG_attempts']=s2018['FG'].map(lambda x: x.split('-')[-1]) #when filled na with '0'

# %%
s2018

# %%
s2018.drop(['3PT','FG','FT','date'],axis=1,inplace=True)

# %%
s2018.info()

# %%
import clean as c
# %load_ext autoreload
# %autoreload 2

# %%
season=pd.read_csv('data/2018.csv')

# %%
c.create_hometeam(season)
c.calc_days_from_opener(season)
c.make_splits(season)

# %%
season
# Out:
#        +/- AST BLK DREB                     Min              Name OREB PF PTS  \
# 0      -10   0   1    3                      24      E.  Ilyasova    3  5   6
# 1       -5   1   1    8                      26        T.  Prince    2  2  10
# 2       -2   1   3    5                      26        D.  Dedmon    2  2   9
# 3       -3   7   0    2                      34      D.  Schroder    0  1  28
# 4       -5   3   0    3                      27      K.  Bazemore    1  2   7
# 5       +8   1   0    2                      22       J.  Collins    3  1  14
# 6       -5   2   0    3                      14       M.  Muscala    1  2   4
# 7      +13   1   1    5                      18        D.  Bembry    1  0   6
# 8      +17   0   0    0                       9       L.  Babbitt    1  0   5
# 9       -1   0   0    1                      11       M.  Delaney    0  1   5
# 10     +14   3   0    3                      26     M.  Belinelli    0  0  20
# 11      +9   1   0    1                       4       J.  Magette    0  2   3
# 12       0   0   0    0                       0        T.  Dorsey    0  0   0
# 13      +1   3   0    6                      38        H.  Barnes    1  0  14
# 14     -18   0   0    5                      24      D.  Nowitzki    1  3  10
# 15      -9   2   0    0                      32       Y.  Ferrell    0  2   9
# 16      +3  10   0    1                      30       D.  Smith J    2  2  16
# 17      -1   5   0    6                      37      W.  Matthews    2  4  15
# 18      -5   0   0    2                      11  D.  Finney-Smith    1  2   2
# 19      +9   0   3    9                      20          N.  Noel    2  2  16
# 20      -4   0   1    0                      14        D.  Powell    0  2   6
# 21      +3   2   0    0                      16        D.  Harris    0  1  10
# 22      -9   5   0    3                      18             J.J.     0  1  13
# 23       0   0   0    0                       0        M.  Kleber    0  0   0
# 24       0   0   0    0                       0        J.  Withey    0  0   0
# 25       0   0   0    0                       0         S.  Mejri    0  0   0
# 26      -5   1   0    5                      21      E.  Ilyasova    1  5   0
# 27     -19   2   0    6                      29        T.  Prince    0  4  15
# 28     -10   2   1    5                      25        D.  Dedmon    2  2  11
# 29      -3   5   0    2                      32      D.  Schroder    1  2  25
# ...    ...  ..  ..  ...                     ...               ...  ... ..  ..
# 30960   +3   0   0    0                       8          E.  Udoh    0  0   6
# 30961  +26   5   0    4                      19          R.  Neto    0  0   8
# 30962  +32   3   0    4                      28         A.  Burks    1  5  27
# 30963    0   0   0    0     DNP-SORE LEFT ANKLE          R.  Hood    0  0   0
# 30964  +10   1   0    2                      20       J.  Jerebko    2  2   9
# 30965   +1   6   0    4                      38        J.  Ingles    1  1  10
# 30966   -4   2   2    4                      34          E.  Udoh    5  3  16
# 30967   +2   3   0    1                      41         R.  Rubio    1  4  21
# 30968   -8   4   1    4                      31      D.  Mitchell    1  4  16
# 30969  +10   1   0    3                      14       R.  O'Neale    1  1  10
# 30970   -8   0   0    0                       9     T.  Sefolosha    0  1   2
# 30971   -1   0   0    0                       5         A.  Burks    0  1   0
# 30972   +5   2   0    6                      15          R.  Hood    0  0   7
# 30973   +8   4   0    4                      33       J.  Johnson    0  0  16
# 30974    0   0   0    0  DNP-RIGHT ANKLE SPRAIN        D.  Favors    0  0   0
# 30975    0   0   0    0                       0       T.  Bradley    0  0   0
# 30976    0   0   0    0                       0   N.  Mitrou-Long    0  0   0
# 30977   +5   2   0    5                      27        M.  Morris    1  3   8
# 30978  +11   1   0    4                      37      O.  Porter J    2  4  14
# 30979   +5   2   0    7                      27        M.  Gortat    1  1   8
# 30980   -3  11   1    4                      42          J.  Wall    2  1  35
# 30981  +12   7   0    5                      40          B.  Beal    0  2  23
# 30982   -7   0   0    2                      13         M.  Scott    0  1   2
# 30983   -9   0   0    0                       4         J.  Smith    0  0   0
# 30984  -15   0   0    5                      25       K.  Oubre J    1  4  12
# 30985   -5   0   0    2                       3       I.  Mahinmi    1  1   0
# 30986   +0   2   0    1                       6    T.  Satoransky    0  0   2
# 30987   -9   0   0    1                      17         J.  Meeks    1  0   0
# 30988    0   0   0    0                       0      D.  Robinson    0  0   0
# 30989    0   0   0    0                       0       T.  Frazier    0  0   0
#
#       REB     ...           team Position  home_team  days_after_opener  \
# 0       6     ...          Hawks       PF      False             1 days
# 1      10     ...          Hawks       SF      False             1 days
# 2       7     ...          Hawks        C      False             1 days
# 3       2     ...          Hawks       PG      False             1 days
# 4       4     ...          Hawks       SG      False             1 days
# 5       5     ...          Hawks       PF      False             1 days
# 6       4     ...          Hawks       PF      False             1 days
# 7       6     ...          Hawks       SF      False             1 days
# 8       1     ...          Hawks       SF      False             1 days
# 9       1     ...          Hawks       PG      False             1 days
# 10      3     ...          Hawks       SG      False             1 days
# 11      1     ...          Hawks        G      False             1 days
# 12      0     ...          Hawks       SG      False             1 days
# 13      7     ...      Mavericks       SF       True             1 days
# 14      6     ...      Mavericks        C       True             1 days
# 15      0     ...      Mavericks       PG       True             1 days
# 16      3     ...      Mavericks       PG       True             1 days
# 17      8     ...      Mavericks       SG       True             1 days
# 18      3     ...      Mavericks       SF       True             1 days
# 19     11     ...      Mavericks        C       True             1 days
# 20      0     ...      Mavericks        C       True             1 days
# 21      0     ...      Mavericks       PG       True             1 days
# 22      3     ...      Mavericks       PG       True             1 days
# 23      0     ...      Mavericks       PF       True             1 days
# 24      0     ...      Mavericks        C       True             1 days
# 25      0     ...      Mavericks        C       True             1 days
# 26      6     ...          Hawks       PF      False             3 days
# 27      6     ...          Hawks       SF      False             3 days
# 28      7     ...          Hawks        C      False             3 days
# 29      3     ...          Hawks       PG      False             3 days
# ...    ..     ...            ...      ...        ...                ...
# 30960   0     ...           Jazz        C       True            48 days
# 30961   4     ...           Jazz       PG       True            48 days
# 30962   5     ...           Jazz       SG       True            48 days
# 30963   0     ...           Jazz       SG       True            48 days
# 30964   4     ...           Jazz       PF      False            85 days
# 30965   5     ...           Jazz       SF      False            85 days
# 30966   9     ...           Jazz        C      False            85 days
# 30967   2     ...           Jazz       PG      False            85 days
# 30968   5     ...           Jazz       SG      False            85 days
# 30969   4     ...           Jazz       SF      False            85 days
# 30970   0     ...           Jazz       SF      False            85 days
# 30971   0     ...           Jazz       SG      False            85 days
# 30972   6     ...           Jazz       SG      False            85 days
# 30973   4     ...           Jazz       SG      False            85 days
# 30974   0     ...           Jazz       PF      False            85 days
# 30975   0     ...           Jazz        C      False            85 days
# 30976   0     ...           Jazz        G      False            85 days
# 30977   6     ...        Wizards       PF       True            85 days
# 30978   6     ...        Wizards       SF       True            85 days
# 30979   8     ...        Wizards        C       True            85 days
# 30980   6     ...        Wizards       PG       True            85 days
# 30981   5     ...        Wizards       SG       True            85 days
# 30982   2     ...        Wizards       PF       True            85 days
# 30983   0     ...        Wizards       PF       True            85 days
# 30984   6     ...        Wizards       SF       True            85 days
# 30985   3     ...        Wizards        C       True            85 days
# 30986   1     ...        Wizards       SG       True            85 days
# 30987   2     ...        Wizards       SG       True            85 days
# 30988   0     ...        Wizards       SF       True            85 days
# 30989   0     ...        Wizards       PG       True            85 days
#
#       FT_made FT_attempts  3PT_made 3PT_attempts FG_made FG_attempts
# 0           2           2         0            1       2           4
# 1           2           2         0            0       4          10
# 2           3           4         0            0       3           6
# 3           1           2         1            3      13          26
# 4           0           0         1            1       3           7
# 5           2           3         0            0       6          10
# 6           0           0         0            1       2           3
# 7           0           0         0            1       3           6
# 8           0           0         1            2       2           3
# 9           0           0         1            2       2           4
# 10          2           2         4            6       7          14
# 11          0           0         1            1       1           1
# 12          0           0         0            0       0           0
# 13          8           9         0            6       3          13
# 14          0           1         2            7       4          14
# 15          0           0         3            4       3           7
# 16          3           4         1            4       6          12
# 17          0           0         5            9       5          12
# 18          0           0         0            2       1           3
# 19          4           4         0            0       6           6
# 20          0           0         2            3       2           3
# 21          1           1         1            5       4           9
# 22          2           2         3            5       4           7
# 23          0           0         0            0       0           0
# 24          0           0         0            0       0           0
# 25          0           0         0            0       0           0
# 26          0           0         0            3       0           4
# 27          1           1         2            4       6          13
# 28          0           0         1            1       5           9
# 29          3           3         0            2      11          21
# ...       ...         ...       ...          ...     ...         ...
# 30960       0           0         0            0       3           4
# 30961       1           2         1            1       3           5
# 30962       6           6         3            5       9          13
# 30963       0           0         0            0       0           0
# 30964       3           4         0            1       3           6
# 30965       1           1         1            6       4          12
# 30966       2           2         0            0       7          10
# 30967       0           0         3            5       9          17
# 30968       0           0         2           10       7          20
# 30969       1           2         1            1       4           4
# 30970       0           0         0            0       1           1
# 30971       0           0         0            1       0           2
# 30972       0           0         1            5       3          11
# 30973       3           4         3            4       5           9
# 30974       0           0         0            0       0           0
# 30975       0           0         0            0       0           0
# 30976       0           0         0            0       0           0
# 30977       0           0         2            3       3           4
# 30978       2           2         2            4       5           9
# 30979       0           0         0            0       4           7
# 30980       4           7         3            6      14          27
# 30981       4           6         1            5       9          19
# 30982       0           0         0            0       1           1
# 30983       0           0         0            0       0           1
# 30984       2           2         2            3       4           5
# 30985       0           0         0            0       0           0
# 30986       0           0         0            0       1           1
# 30987       0           0         0            4       0           4
# 30988       0           0         0            0       0           0
# 30989       0           0         0            0       0           0
#
# [30990 rows x 24 columns]
